# %%
import pandas as pd
import numpy as np
import plotly.express as pe
from sklearn.ensemble import IsolationForest

# %% [markdown]
# # Loading dataset

# %%
# Load dataset
data_dir_path = '../src/data/'
data_trainset = pd.read_csv(data_dir_path + "/train.csv")
data_testset = pd.read_csv(data_dir_path + '/test.csv')

# %% [markdown]
# # Dataset Analysis

# %%
# missing values in the dataset
missing_values =data_trainset.isna().sum().sum()
print("Missing values in the dataset : ", missing_values)
# Out:
# Missing values in the dataset :  0

# %%
# Duplicated values in the dataset
duplicated_values =data_trainset.duplicated().sum()
print("Duplicates values in the dataset : ", duplicated_values)
# Out:
# Duplicates values in the dataset :  0

# %%
# Statistics of the dataset using the describe function.
statistics_data = data_trainset.describe()
statistics_data
# Out:
#                 id     margin1     margin2     margin3     margin4  \
# count   990.000000  990.000000  990.000000  990.000000  990.000000
# mean    799.595960    0.017412    0.028539    0.031988    0.023280
# std     452.477568    0.019739    0.038855    0.025847    0.028411
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     415.250000    0.001953    0.001953    0.013672    0.005859
# 50%     802.500000    0.009766    0.011719    0.025391    0.013672
# 75%    1195.500000    0.025391    0.041016    0.044922    0.029297
# max    1584.000000    0.087891    0.205080    0.156250    0.169920
#
#           margin5     margin6     margin7     margin8     margin9  ...  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  ...
# mean     0.014264    0.038579    0.019202    0.001083    0.007167  ...
# std      0.018390    0.052030    0.017511    0.002743    0.008933  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%      0.001953    0.000000    0.005859    0.000000    0.001953  ...
# 50%      0.007812    0.015625    0.015625    0.000000    0.005859  ...
# 75%      0.017578    0.056153    0.029297    0.000000    0.007812  ...
# max      0.111330    0.310550    0.091797    0.031250    0.076172  ...
#
#         texture55   texture56   texture57   texture58   texture59   texture60  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.036501    0.005024    0.015944    0.011586    0.016108    0.014017
# std      0.063403    0.019321    0.023214    0.025040    0.015335    0.060151
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000977    0.000000    0.004883    0.000000
# 50%      0.004883    0.000000    0.005859    0.000977    0.012695    0.000000
# 75%      0.043701    0.000000    0.022217    0.009766    0.021484    0.000000
# max      0.429690    0.202150    0.172850    0.200200    0.106450    0.578130
#
#         texture61   texture62   texture63   texture64
# count  990.000000  990.000000  990.000000  990.000000
# mean     0.002688    0.020291    0.008989    0.019420
# std      0.011415    0.039040    0.013791    0.022768
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000977
# 50%      0.000000    0.003906    0.002930    0.011719
# 75%      0.000000    0.023438    0.012695    0.029297
# max      0.151370    0.375980    0.086914    0.141600
#
# [8 rows x 193 columns]

# %% [markdown]
# The dataset appears to contain a number of outliers, with some maximum values significantly diverging from the mean. Let's proceed to investigate this using histograms and boxplots."

# %%
# Histograms of the dataset based on the specified column
fig = pe.histogram(data_trainset, ['margin1', 'margin2', 'margin3'])
fig.show()
# Out:
# <div>                            <div id="27924922-548f-4fa4-8f65-c4942f9fd7c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
#
# Our initial hypothesis stands confirmed the histogram and boxplot reveal the presence of outliers within our dataset. We'll now move forward with replacing these outliers with better values

# %% [markdown]
# # Replacing outliers

# %%
# Drop the "id" column
data_trainset = data_trainset.drop(columns="id", axis=1)

# %%
outliers_percentage = {}

for column in data_trainset.columns:
     # Check if the column is numeric
    if data_trainset[column].dtype in ['int64', 'float64']: 
        # Isolation Forest requires 2D data, so reshape the column data
        data = data_trainset[column].values.reshape(-1, 1)
        
        clf = IsolationForest(random_state=42)
        preds = clf.fit_predict(data)
        
        # Calculate the number of outliers
        n_outliers = np.sum(preds == -1)
        
        # Replace outliers with NaN
        data_trainset.loc[preds == -1, column] = np.nan
        
        # Calculate the percentage of outliers
        percentage = (n_outliers / len(data)) * 100
        outliers_percentage[column] = percentage

# Print the percentage of outliers for each numeric column
for column, percentage in outliers_percentage.items():
    print(f"{column}: {percentage:.2f}% outliers")
# Out:
# margin1: 36.26% outliers
# margin2: 35.05% outliers
# margin3: 33.13% outliers
# margin4: 24.34% outliers
# margin5: 22.63% outliers
# margin6: 37.88% outliers
# margin7: 40.61% outliers
# margin8: 18.69% outliers
# margin9: 24.65% outliers
# margin10: 47.58% outliers
# margin11: 40.51% outliers
# margin12: 55.25% outliers
# margin13: 24.24% outliers
# margin14: 33.84% outliers
# margin15: 58.79% outliers
# margin16: 1.31% outliers
# margin17: 30.40% outliers
# margin18: 17.17% outliers
# margin19: 15.35% outliers
# margin20: 30.30% outliers
# margin21: 46.57% outliers
# margin22: 31.62% outliers
# margin23: 8.18% outliers
# margin24: 32.53% outliers
# margin25: 40.10% outliers
# margin26: 31.01% outliers
# margin27: 33.13% outliers
# margin28: 32.32% outliers
# margin29: 40.91% outliers
# margin30: 23.03% outliers
# margin31: 32.22% outliers
# margin32: 31.31% outliers
# margin33: 52.93% outliers
# margin34: 30.61% outliers
# margin35: 36.36% outliers
# margin36: 39.19% outliers
# margin37: 44.34% outliers
# margin38: 35.56% outliers
# margin39: 59.90% outliers
# margin40: 32.53% outliers
# margin41: 24.65% outliers
# margin42: 26.46% outliers
# margin43: 25.15% outliers
# margin44: 34.14% outliers
# margin45: 29.80% outliers
# margin46: 36.46% outliers
# margin47: 50.00% outliers
# margin48: 43.03% outliers
# margin49: 32.73% outliers
# margin50: 45.25% outliers
# margin51: 36.97% outliers
# margin52: 20.10% outliers
# margin53: 47.68% outliers
# margin54: 35.86% outliers
# margin55: 24.55% outliers
# margin56: 33.94% outliers
# margin57: 32.83% outliers
# margin58: 25.25% outliers
# margin59: 18.48% outliers
# margin60: 20.30% outliers
# margin61: 15.86% outliers
# margin62: 23.43% outliers
# margin63: 35.35% outliers
# margin64: 22.12% outliers
# shape1: 16.26% outliers
# shape2: 17.47% outliers
# shape3: 17.78% outliers
# shape4: 18.69% outliers
# shape5: 21.72% outliers
# shape6: 21.11% outliers
# shape7: 18.69% outliers
# shape8: 16.57% outliers
# shape9: 17.98% outliers
# shape10: 16.77% outliers
# shape11: 17.98% outliers
# shape12: 18.99% outliers
# shape13: 17.68% outliers
# shape14: 19.80% outliers
# shape15: 22.63% outliers
# shape16: 23.84% outliers
# shape17: 22.93% outliers
# shape18: 25.45% outliers
# shape19: 24.44% outliers
# shape20: 24.85% outliers
# shape21: 24.14% outliers
# shape22: 25.35% outliers
# shape23: 24.65% outliers
# shape24: 22.93% outliers
# shape25: 19.90% outliers
# shape26: 21.92% outliers
# shape27: 18.59% outliers
# shape28: 21.01% outliers
# shape29: 19.60% outliers
# shape30: 17.27% outliers
# shape31: 17.68% outliers
# shape32: 15.86% outliers
# shape33: 16.87% outliers
# shape34: 14.75% outliers
# shape35: 18.69% outliers
# shape36: 20.61% outliers
# shape37: 19.60% outliers
# shape38: 20.51% outliers
# shape39: 20.91% outliers
# shape40: 24.34% outliers
# shape41: 26.16% outliers
# shape42: 22.02% outliers
# shape43: 21.31% outliers
# shape44: 21.72% outliers
# shape45: 21.31% outliers
# shape46: 23.54% outliers
# shape47: 24.04% outliers
# shape48: 23.03% outliers
# shape49: 23.33% outliers
# shape50: 20.51% outliers
# shape51: 21.82% outliers
# shape52: 19.29% outliers
# shape53: 18.28% outliers
# shape54: 18.48% outliers
# shape55: 19.19% outliers
# shape56: 21.62% outliers
# shape57: 19.80% outliers
# shape58: 20.20% outliers
# shape59: 20.10% outliers
# shape60: 23.94% outliers
# shape61: 25.25% outliers
# shape62: 21.62% outliers
# shape63: 18.99% outliers
# shape64: 19.70% outliers
# texture1: 19.70% outliers
# texture2: 23.74% outliers
# texture3: 37.68% outliers
# texture4: 35.86% outliers
# texture5: 52.63% outliers
# texture6: 31.62% outliers
# texture7: 15.25% outliers
# texture8: 38.38% outliers
# texture9: 15.76% outliers
# texture10: 29.19% outliers
# texture11: 35.86% outliers
# texture12: 24.44% outliers
# texture13: 20.10% outliers
# texture14: 25.05% outliers
# texture15: 15.15% outliers
# texture16: 30.30% outliers
# texture17: 26.46% outliers
# texture18: 24.65% outliers
# texture19: 14.44% outliers
# texture20: 24.55% outliers
# texture21: 15.05% outliers
# texture22: 39.80% outliers
# texture23: 26.77% outliers
# texture24: 34.65% outliers
# texture25: 26.16% outliers
# texture26: 29.90% outliers
# texture27: 35.15% outliers
# texture28: 29.49% outliers
# texture29: 19.90% outliers
# texture30: 34.04% outliers
# texture31: 18.18% outliers
# texture32: 31.52% outliers
# texture33: 23.64% outliers
# texture34: 23.94% outliers
# texture35: 36.16% outliers
# texture36: 16.06% outliers
# texture37: 23.54% outliers
# texture38: 31.62% outliers
# texture39: 28.69% outliers
# texture40: 22.73% outliers
# texture41: 21.31% outliers
# texture42: 36.67% outliers
# texture43: 26.77% outliers
# texture44: 30.71% outliers
# texture45: 34.55% outliers
# texture46: 52.22% outliers
# texture47: 31.92% outliers
# texture48: 40.81% outliers
# texture49: 20.91% outliers
# texture50: 22.73% outliers
# texture51: 28.08% outliers
# texture52: 40.91% outliers
# texture53: 32.53% outliers
# texture54: 17.07% outliers
# texture55: 38.38% outliers
# texture56: 21.31% outliers
# texture57: 32.32% outliers
# texture58: 24.85% outliers
# texture59: 28.69% outliers
# texture60: 20.30% outliers
# texture61: 10.51% outliers
# texture62: 27.17% outliers
# texture63: 47.68% outliers
# texture64: 37.27% outliers

# %%
# Set the threshold to 50% of the number of rows in the dataset
threshold = len(data_trainset) * 0.5

# Drop columns from the DataFrame where more than 50% of the values are NaN
data_trainset_cleaned = data_trainset.dropna(axis='columns', thresh=threshold)
data_trainset_cleaned.to_csv('../src/data/data_trainset_cleaned.csv', index=False)

# %%
statistics_data = data_trainset_cleaned.describe()
statistics_data
# Out:
#           margin1     margin2     margin3     margin4     margin5     margin6  \
# count  631.000000  643.000000  662.000000  749.000000  766.000000  615.000000
# mean     0.005739    0.006525    0.023570    0.013661    0.006160    0.007562
# std      0.006283    0.007889    0.011235    0.009461    0.005769    0.010334
# min      0.000000    0.000000    0.007812    0.001953    0.000000    0.000000
# 25%      0.000000    0.000000    0.013672    0.005859    0.000000    0.000000
# 50%      0.003906    0.003906    0.021484    0.011719    0.003906    0.003906
# 75%      0.011719    0.009766    0.031250    0.019531    0.009766    0.011719
# max      0.019531    0.031250    0.050781    0.035156    0.019531    0.042969
#
#           margin7  margin8     margin9    margin10  ...   texture55  \
# count  588.000000    805.0  746.000000  519.000000  ...  610.000000
# mean     0.010908      0.0    0.004513    0.016080  ...    0.002318
# std      0.007615      0.0    0.003582    0.006560  ...    0.004819
# min      0.000000      0.0    0.000000    0.005859  ...    0.000000
# 25%      0.005859      0.0    0.000000    0.011719  ...    0.000000
# 50%      0.011719      0.0    0.005859    0.015625  ...    0.000000
# 75%      0.017578      0.0    0.005859    0.021484  ...    0.002930
# max      0.023438      0.0    0.011719    0.027344  ...    0.032227
#
#        texture56   texture57   texture58   texture59   texture60  texture61  \
# count      779.0  670.000000  744.000000  706.000000  789.000000      886.0
# mean         0.0    0.003930    0.001592    0.012092    0.000032        0.0
# std          0.0    0.004988    0.002528    0.007573    0.000175        0.0
# min          0.0    0.000000    0.000000    0.000000    0.000000        0.0
# 25%          0.0    0.000000    0.000000    0.006836    0.000000        0.0
# 50%          0.0    0.001953    0.000000    0.011719    0.000000        0.0
# 75%          0.0    0.005859    0.002197    0.018555    0.000000        0.0
# max          0.0    0.023438    0.009766    0.026367    0.000977        0.0
#
#         texture62   texture63   texture64
# count  721.000000  518.000000  621.000000
# mean     0.003585    0.001190    0.009187
# std      0.005450    0.002507    0.011594
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000977    0.000000    0.002930
# 75%      0.004883    0.000000    0.015625
# max      0.022461    0.008789    0.041992
#
# [8 rows x 186 columns]
